# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tested.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# Display the first five rows
print(df.head())

# Get a concise summary of the DataFrame
print(df.info())

# Generate descriptive statistics
print(df.describe(include='all'))
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# None
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# unique         NaN         NaN         NaN       363         NaN
# top            NaN         NaN         NaN  PC 17608         NaN
# freq           NaN         NaN         NaN         5         NaN
# mean     30.272590    0.447368    0.392344       NaN   35.627188
# std      14.181209    0.896760    0.981429       NaN   55.907576
# min       0.170000    0.000000    0.000000       NaN    0.000000
# 25%      21.000000    0.000000    0.000000       NaN    7.895800
# 50%      27.000000    0.000000    0.000000       NaN   14.454200
# 75%      39.000000    1.000000    0.000000       NaN   31.500000
# max      76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked
# count                91      418
# unique               76        3
# top     B57 B59 B63 B66        S
# freq                  3      270
# mean                NaN      NaN
# std                 NaN      NaN
# min                 NaN      NaN
# 25%                 NaN      NaN
# 50%                 NaN      NaN
# 75%                 NaN      NaN
# max                 NaN      NaN

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(df.columns)
df.drop(columns=['Cabin'], inplace=True, errors='ignore')

# Fill missing 'Age' values with the median age
df = df.assign(Age=df['Age'].fillna(df['Age'].median()))

# Fill missing 'Embarked' values with the mode
df = df.assign(Embarked=df['Embarked'].fillna(df['Embarked'].mode()[0]))
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot for 'Fare'
sns.boxplot(x=df['Fare'])
plt.show()

# %%
# Check for duplicates
print(df.duplicated().sum())

# Remove duplicates
df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
# Convert 'Name' to lowercase
df['Name'] = df['Name'].str.lower()

# Standardize 'Sex' values
df['Sex'] = df['Sex'].str.lower()
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                kelly, mr. james    male  34.5      0      0
# 1                wilkes, mrs. james (ellen needs)  female  47.0      1      0
# 2                       myles, mr. thomas francis    male  62.0      0      0
# 3                                wirz, mr. albert    male  27.0      0      0
# 4    hirvonen, mrs. alexander (helga e lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            spector, mr. woolf    male  27.0      0      0
# 414                  oliva y ocana, dona. fermina  female  39.0      0      0
# 415                  saether, mr. simon sivertsen    male  38.5      0      0
# 416                           ware, mr. frederick    male  27.0      0      0
# 417                      peter, master. michael j    male  27.0      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# 3                315154    8.6625        S
# 4               3101298   12.2875        S
# ..                  ...       ...      ...
# 413           A.5. 3236    8.0500        S
# 414            PC 17758  108.9000        C
# 415  SOTON/O.Q. 3101262    7.2500        S
# 416              359309    8.0500        S
# 417                2668   22.3583        C
#
# [418 rows x 11 columns]

# %%
# Random sample of 10% of the data
sample_df = df.sample(frac=0.1, random_state=1)
sample_df
# Out:
#      PassengerId  Survived  Pclass  \
# 358         1250         0       3
# 164         1056         0       2
# 17           909         0       3
# 67           959         0       1
# 4            896         1       3
# 377         1269         0       2
# 214         1106         1       3
# 290         1182         0       1
# 381         1273         0       3
# 5            897         0       3
# 338         1230         0       2
# 227         1119         1       3
# 191         1083         0       1
# 305         1197         1       1
# 351         1243         0       2
# 409         1301         1       3
# 230         1122         0       2
# 185         1077         0       2
# 101          993         0       2
# 62           954         0       3
# 291         1183         1       3
# 251         1143         0       3
# 228         1120         0       3
# 29           921         0       3
# 256         1148         0       3
# 401         1293         0       2
# 139         1031         0       3
# 298         1190         0       1
# 388         1280         0       3
# 47           939         0       3
# 127         1019         1       3
# 272         1164         1       1
# 186         1078         1       2
# 85           977         0       3
# 232         1124         0       3
# 106          998         0       3
# 373         1265         0       2
# 310         1202         0       3
# 329         1221         0       2
# 402         1294         1       1
# 132         1024         1       3
# 78           970         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 358                               o'keefe, mr. patrick    male  27.0      0
# 164                      peruschitz, rev. joseph maria    male  41.0      0
# 17                                   assaf, mr. gerios    male  21.0      0
# 67                      moore, mr. clarence bloomfield    male  47.0      0
# 4         hirvonen, mrs. alexander (helga e lindqvist)  female  22.0      1
# 377                       cotterill, mr. henry harry""    male  21.0      0
# 214             andersson, miss. ida augusta margareta  female  38.0      4
# 290                rheims, mr. george alexander lucien    male  27.0      0
# 381                                  foley, mr. joseph    male  26.0      0
# 5                           svensson, mr. johan cervin    male  14.0      0
# 338                               denbury, mr. herbert    male  25.0      0
# 227                             mcneill, miss. bridget  female  27.0      0
# 191                             salomon, mr. abraham l    male  27.0      0
# 305  crosby, mrs. edward gifford (catherine elizabe...  female  64.0      1
# 351                          stokes, mr. philip joseph    male  25.0      0
# 409                          peacock, miss. treasteall  female   3.0      1
# 230                        sweet, mr. george frederick    male  14.0      0
# 185                          maybery, mr. frank hubert    male  40.0      0
# 101                                 weisz, mr. leopold    male  27.0      1
# 62                        bjorklund, mr. ernst herbert    male  18.0      0
# 291             daly, miss. margaret marcella maggie""  female  30.0      0
# 251           abrahamsson, mr. abraham august johannes    male  20.0      0
# 228                          everett, mr. thomas james    male  40.5      0
# 29                                   samaan, mr. elias    male  27.0      2
# 256                                    mahon, mr. john    male  27.0      0
# 401                                    gale, mr. harry    male  38.0      1
# 139                     goodwin, mr. charles frederick    male  40.0      1
# 298                         loring, mr. joseph holland    male  30.0      0
# 388                               canavan, mr. patrick    male  21.0      0
# 47                            shaughnessy, mr. patrick    male  27.0      0
# 127                                mccoy, miss. alicia  female  27.0      2
# 272      clark, mrs. walter miller (virginia mcdowell)  female  26.0      1
# 186               phillips, miss. alice frances louisa  female  21.0      0
# 85                                  khalil, mr. betros    male  27.0      1
# 232                            wiklund, mr. karl johan    male  21.0      1
# 106                                buckley, mr. daniel    male  21.0      0
# 373                             harbeck, mr. william h    male  44.0      0
# 310                               cacic, mr. jego grga    male  18.0      0
# 329                                enander, mr. ingvar    male  21.0      0
# 402                     gibson, miss. dorothy winifred  female  22.0      0
# 132                      lefebre, mrs. frank (frances)  female  27.0      0
# 78                      aldworth, mr. charles augustus    male  30.0      0
#
#      Parch              Ticket      Fare Embarked
# 358      0              368402    7.7500        Q
# 164      0              237393   13.0000        S
# 17       0                2692    7.2250        C
# 67       0              113796   42.4000        S
# 4        1             3101298   12.2875        S
# 377      0               29107   11.5000        S
# 214      2              347091    7.7750        S
# 290      0            PC 17607   39.6000        S
# 381      0              330910    7.8792        Q
# 5        0                7538    9.2250        S
# 338      0          C.A. 31029   31.5000        S
# 227      0              370368    7.7500        Q
# 191      0              111163   26.0000        S
# 305      1              112901   26.5500        S
# 351      0        F.C.C. 13540   10.5000        S
# 409      1  SOTON/O.Q. 3101315   13.7750        S
# 230      0              220845   65.0000        S
# 185      0              239059   16.0000        S
# 101      0              228414   26.0000        S
# 62       0              347090    7.7500        S
# 291      0              382650    6.9500        Q
# 251      0    SOTON/O2 3101284    7.9250        S
# 228      0           C.A. 6212   15.1000        S
# 29       0                2662   21.6792        C
# 256      0           AQ/4 3130    7.7500        Q
# 401      0               28664   21.0000        S
# 139      6             CA 2144   46.9000        S
# 298      0              113801   45.5000        S
# 388      0              364858    7.7500        Q
# 47       0              370374    7.7500        Q
# 127      0              367226   23.2500        Q
# 272      0               13508  136.7792        C
# 186      1         S.O./P.P. 2   21.0000        S
# 85       0                2660   14.4542        C
# 232      0             3101266    6.4958        S
# 106      0              330920    7.8208        Q
# 373      0              248746   13.0000        S
# 310      0              315091    8.6625        S
# 329      0              236854   13.0000        S
# 402      1              112378   59.4000        C
# 132      4                4133   25.4667        S
# 78       0              248744   13.0000        S

# %%
# Save to a new CSV file
df.to_csv('cleaned_titanic.csv', index=False)
